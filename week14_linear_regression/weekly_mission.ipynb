# %% [markdown]
# #  주간 미션: 펭귄 몸무게 회귀식 만들기
#
# 데이터 셋 링크: https://www.kaggle.com/datasets/parulpandey/palmer-archipelago-antarctica-penguin-data
#
# 펭귄들의 종, 서식 지역, 부리 길이와 부리 깊이, 날개(?) 사이즈, 성별, 그리고 몸무게 데이터 셋이 있습니다. 선형 회귀를 이용하여 펭귄들의 몸무게를 예측하는 회귀식을 만들어보세요.
#
# ### 요구 사항
# - 기본적인 EDA를 수행해주세요.
# - ANOVA를 활용하여 서식지별로 펭귄들의 몸무게가 같은지 다른지 검정하세요.
# - 다중 선형회귀, ridge, lasso를 활용하여 회귀식을 만들고 타당성을 검정하세요.
# - 결과를 블로그 포스팅으로 정리해주세요.
#
# ![image.png](attachment:0c2f6afa-fbe4-4cc5-8d2e-8d229689c5c8.png)

# %%
from utils import load_penguin_dataset

x_train, x_test, y_train, y_test = load_penguin_dataset()

# %%
x_train
# Out:
#        species     island  culmen_length_mm  culmen_depth_mm  \
# 225     Gentoo     Biscoe              46.5             13.5
# 119     Adelie  Torgersen              41.1             18.6
# 181  Chinstrap      Dream              52.8             20.0
# 167  Chinstrap      Dream              50.5             19.6
# 226     Gentoo     Biscoe              45.4             14.6
# ..         ...        ...               ...              ...
# 205  Chinstrap      Dream              50.7             19.7
# 54      Adelie     Biscoe              34.5             18.1
# 295     Gentoo     Biscoe              48.6             16.0
# 212  Chinstrap      Dream              51.9             19.5
# 304     Gentoo     Biscoe              44.9             13.8
#
#      flipper_length_mm     sex
# 225              210.0  FEMALE
# 119              189.0    MALE
# 181              205.0    MALE
# 167              201.0    MALE
# 226              211.0  FEMALE
# ..                 ...     ...
# ...
